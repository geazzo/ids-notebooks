# %%
import nltk
from nltk.corpus import gutenberg

texts = ['whitman-leaves.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt']
for text in texts:
    print ("\n\n"+text)
    words = [w for w in gutenberg.words(text)]
    
    frequencies = nltk.FreqDist([w for w in words if len(w) > 4 and w.lower() == w])
    for e in frequencies.most_common(10):
        print (e)
    frequencies.plot(100)
# Out:
# whitman-leaves.txt
# ('their', 353)
# ('shall', 251)
# ('these', 241)
# ('there', 238)
# ('through', 229)
# ('earth', 226)
# ('night', 212)
# ('myself', 178)
# ('those', 168)
# ('every', 165)
# shakespeare-caesar.txt
# ('shall', 107)
# ('their', 57)
# ('heere', 41)
# ('would', 40)
# ('selfe', 39)
# ('should', 38)
# ('there', 34)
# ('heare', 34)
# ('these', 32)
# ('feare', 28)
# shakespeare-hamlet.txt
# ('shall', 104)
# ('selfe', 66)
# ('there', 66)
# ('would', 60)
# ('should', 52)
# ('speake', 48)
# ('their', 46)
# ('thinke', 42)
# ('heere', 42)
# ('which', 39)
# shakespeare-macbeth.txt
# ('their', 57)
# ('shall', 48)
# ('which', 44)
# ('would', 42)
# ('should', 41)
# ('selfe', 34)
# ('there', 32)
# ('feare', 27)
# ('great', 25)
# ('speake', 25)

# %%
help(frequencies.plot)

# %%
frequencies.plot(100)
